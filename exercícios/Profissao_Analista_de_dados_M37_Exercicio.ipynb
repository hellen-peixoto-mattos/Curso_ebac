# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Amazon Web Services;</li>
#   <li>AWS IAM;</li>
#   <li>AWS S3;</li>
#   <li>AWS Athena.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Amazon Web Services

# %% [markdown]
#  1. Crie uma conta na [AWS](https://portal.aws.amazon.com/);
#  1. Acesse a sua conta e selecione a região mais próxima da sua residência.

# %% [markdown]
# ## 2\. AWS S3

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('iris.csv', index=False, header=False)

# %% [markdown]
# ## 3\. AWS Athena

# %% [markdown]
# Replique as atividades do item 4.3 em sua conta.

# %% [markdown]
# Tabela externa executada.
#
# ```
# CREATE EXTERNAL TABLE iris (
# sepal_length double,
# sepal_width double,
# petal_length double,
# petal_width double,
# specie string
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES ('separatorChar'=',')
# LOCATION 's3://modelo37-ebac/'
# ```

# %% [markdown]
# Query 1:
#
# `SELECT * FROM iris LIMIT 10;`

# %%
pd.read_csv('query_1m37.csv')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  specie
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
#   Query 2:
#
# ```
# SELECT
#   specie,
#   round(avg(sepal_length), 4) as avg_sepal_length,
#   round(avg(sepal_width), 4) as avg_sepal_width,
#   round(avg(petal_length), 4) as avg_petal_length,
#   round(avg(petal_width), 4) as avg_petal_width
# FROM iris
# GROUP BY specie;
# ```

# %%
pd.read_csv('query_2m37.csv')
# Out:
#        specie  avg_sepal_length  avg_sepal_width  avg_petal_length  \
# 0   virginica             6.588            2.974             5.552
# 1      setosa             5.006            3.428             1.462
# 2  versicolor             5.936            2.770             4.260
#
#    avg_petal_width
# 0            2.026
# 1            0.246
# 2            1.326
